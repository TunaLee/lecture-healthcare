# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#             ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0    TRAIN_000            4      103             60             33      192
# 1    TRAIN_001           10      133             68              0        0
# 2    TRAIN_002            4      112             78             40        0
# 3    TRAIN_003            1      119             88             41      170
# 4    TRAIN_004            1      114             66             36      200
# ..         ...          ...      ...            ...            ...      ...
# 647  TRAIN_647            1       91             64             24        0
# 648  TRAIN_648           10      122             68              0        0
# 649  TRAIN_649            8       84             74             31        0
# 650  TRAIN_650            2       81             72             15       76
# 651  TRAIN_651            1      107             68             19        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.index = ['a', 'b', 'c', 'd']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.index = ['a', 'b', 'c', 'd']
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/site-packages/pandas/core/generic.py:6335, in NDFrame.__setattr__(self, name, value)
#    6333 try:
#    6334     object.__getattribute__(self, name)
# -> 6335     return object.__setattr__(self, name, value)
#    6336 except AttributeError:
#    6337     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File /opt/anaconda3/envs/myenv/lib/python3.12/site-packages/pandas/core/generic.py:817, in NDFrame._set_axis(self, axis, labels)
#     812 """
#     813 This is called from the cython code when we set the `index` attribute
#     814 directly, e.g. `series.index = [1, 2, 3]`.
#     815 """
#     816 labels = ensure_index(labels)
# --> 817 self._mgr.set_axis(axis, labels)
# ...

# %%
import pandas as pd

data = {
    "Name": ["Tom", "Jane", "Alice", "Bob"],
    "Age": [28, 34, 29, 42],
    "Score": [85, 92, 88, 75]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Score
# 0    Tom   28     85
# 1   Jane   34     92
# 2  Alice   29     88
# 3    Bob   42     75

# %%
df["Outcome"].value_counts()
# Out:
# Outcome
# 0    424
# 1    228
# Name: count, dtype: int64

# %%
df.get("Outcom",0)
# Out:
# 0

# %%
df["Outcome"].nunique()
# Out:
# 2

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   652.000000  652.000000     652.000000     652.000000  652.000000
# mean      3.923313  120.946319      68.895706      20.440184   80.878834
# std       3.327529   31.992394      19.183843      15.918604  117.748315
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      64.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   34.000000
# 75%       6.000000  142.000000      80.000000      32.000000  126.000000
# max      15.000000  199.000000     114.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  652.000000                652.000000  652.000000  652.000000
# mean    31.947393                  0.465133   33.510736    0.349693
# std      7.460975                  0.329496   11.824817    0.477239
# ...

# %%
# !pip install seaborn

# %%
import seaborn as sns
sns.histplot(df["Glucose"], kde=True)
# Out:
# <Axes: xlabel='Glucose', ylabel='Count'>

# %%
sns.boxplot(x=df["BMI"])
# Out:
# <Axes: xlabel='BMI'>

# %%
df = sns.load_dataset('titanic')

# %%
df.pivot_table(index="sex", columns="class")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.groupby(["sex", "class"])["age"].transform("mean")
# Out:
# /var/folders/6p/kc5wj8m97yv4r_zm5y1n5kk00000gn/T/ipykernel_2282/1632335629.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["sex", "class"])["age"].transform("mean")
# 0      26.507589
# 1      34.611765
# 2      21.750000
# 3      34.611765
# 4      26.507589
#          ...
# 886    30.740707
# 887    34.611765
# 888    21.750000
# 889    41.281386
# 890    26.507589
# Name: age, Length: 891, dtype: float64

# %%
pd.pivot_table(
    df, values="age", index="sex"
)
# Out:
#               age
# sex
# female  27.915709
# male    30.726645

# %%
sns.boxplot(data=df, x='class', y='age')
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
df = sns.load_dataset('titanic')

# %%
df_imp = df.copy()

# 그룹별 중앙값 계산(브로드캐스트용 transform)
age_median = (df_imp
              .groupby(["sex", "class"])["age"]
              .transform("median"))

# age 결측만 그룹 중앙값으로 채우기
df_imp["age"] = df_imp["age"].fillna(age_median)
# Out:
# /var/folders/6p/kc5wj8m97yv4r_zm5y1n5kk00000gn/T/ipykernel_2282/802299597.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(["sex", "class"])["age"]

# %%
df[["age"]].describe()
df_imp[["age"]].describe()
# Out:
#               age
# count  891.000000
# mean    29.112424
# std     13.304424
# min      0.420000
# 25%     21.500000
# 50%     26.000000
# 75%     36.000000
# max     80.000000

# %%
sns.kdeplot(df["age"], label="orig", fill=True)
sns.kdeplot(df_imp["age"], label="imputed", fill=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
mask = (df_imp["class"] == "First") & (df_imp["embark_town"].isna())
df_imp.loc[mask, "embark_town"] = "Cherbourg"

# 2등석에서 비어 있으면 'Southampton'으로
mask = (df_imp["class"] == "Second") & (df_imp["embark_town"].isna())
df_imp.loc[mask, "embark_town"] = "Southampton"

# 3등석에서 비어 있으면 'Southampton'으로
mask = (df_imp["class"] == "Third") & (df_imp["embark_town"].isna())
df_imp.loc[mask, "embark_town"] = "Southampton"

# %%
   df_imp["deck"] = df_imp["deck"].astype("category")
   df_imp["deck"] = df_imp["deck"].cat.add_categories(["Unknown"])
   df_imp["deck"] = df_imp["deck"].fillna("Unknown")

# %%
before = df.isnull().mean().to_frame("null_ratio_before")
after  = df_imp.isnull().mean().to_frame("null_ratio_after")

before.join(after, how="outer").sort_values("null_ratio_after", ascending=False)
# Out:
#              null_ratio_before  null_ratio_after
# embarked              0.002245          0.002245
# adult_male            0.000000          0.000000
# age                   0.198653          0.000000
# alive                 0.000000          0.000000
# alone                 0.000000          0.000000
# class                 0.000000          0.000000
# deck                  0.772166          0.000000
# embark_town           0.002245          0.000000
# fare                  0.000000          0.000000
# parch                 0.000000          0.000000
# pclass                0.000000          0.000000
# sex                   0.000000          0.000000
# sibsp                 0.000000          0.000000
# survived              0.000000          0.000000
# who                   0.000000          0.000000

# %%
sns.barplot(data=df_imp, x="class", y="age", hue="sex", estimator=pd.Series.median)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/6p/kc5wj8m97yv4r_zm5y1n5kk00000gn/T/ipykernel_2282/2812304274.py in ?()
# ----> 1 sns.barplot(data=df_imp, x="class", y="age", hue="sex", estimator=pd.Series.median)
#
# /opt/anaconda3/envs/myenv/lib/python3.12/site-packages/seaborn/categorical.py in ?(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2376
#    2377     # Deprecations to remove in v0.15.0.
#    2378     err_kws, capsize = p._err_kws_backcompat(err_kws, errcolor, errwidth, capsize)
#    2379
# -> 2380     p.plot_bars(
#    2381         aggregator=aggregator,
#    2382         dodge=dodge,
#    2383         width=width,
#
# ...

# %%
df_age = df.copy()

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_age.groupby(['sex', 'class'])["age"].transform('mean')
# Out:
# /var/folders/6p/kc5wj8m97yv4r_zm5y1n5kk00000gn/T/ipykernel_2282/1550460734.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_age.groupby(['sex', 'class'])["age"].transform('mean')
# 0      26.507589
# 1      34.611765
# 2      21.750000
# 3      34.611765
# 4      26.507589
#          ...
# 886    30.740707
# 887    34.611765
# 888    21.750000
# 889    41.281386
# 890    26.507589
# Name: age, Length: 891, dtype: float64

# %%
sns.histplot(data = df, x='age', kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df_age = df.copy()
age_median = df_age.groupby(['sex', 'class'])['age'].transform('median')
# Out:
# /var/folders/6p/kc5wj8m97yv4r_zm5y1n5kk00000gn/T/ipykernel_2282/2405898892.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_median = df_age.groupby(['sex', 'class'])['age'].transform('median')

# %%
df_age['age'] = df_age['age'].fillna(age_median)

# %%
df_age[['age']].describe()
# Out:
#               age
# count  891.000000
# mean    29.112424
# std     13.304424
# min      0.420000
# 25%     21.500000
# 50%     26.000000
# 75%     36.000000
# max     80.000000

# %%
df[['age']].describe()
# Out:
#               age
# count  714.000000
# mean    29.699118
# std     14.526497
# min      0.420000
# 25%     20.125000
# 50%     28.000000
# 75%     38.000000
# max     80.000000

# %%
sns.kdeplot(df["age"], label="orig", fill=True)
sns.kdeplot(df_age["age"], label="imputed", fill=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_deck = df.copy()

if str(df_deck['deck'].dtype) == 'category':
    df_deck['deck'] = df_deck['deck'].cat.add_categories(['Unknown'])
df_deck.loc[df_deck['deck'].isna(), 'deck'] = 'Unknown'

# %%
df_deck
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df['deck'].astype('category')
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: deck, Length: 891, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
pd.crosstab(df["class"], df["embark_town"])
# Out:
# embark_town  Cherbourg  Queenstown  Southampton
# class
# First               85           2          127
# Second              17           3          164
# Third               66          72          353

# %%
pd.crosstab(df["class"], df["embark_town"], normalize="index").round(2)
# Out:
# embark_town  Cherbourg  Queenstown  Southampton
# class
# First             0.40        0.01         0.59
# Second            0.09        0.02         0.89
# Third             0.13        0.15         0.72

# %%
df['age'] = df_age['age']

# %%
mask = (df["class"] == "First") & (df["embark_town"].isna())
df.loc[mask, "embark_town"] = "Cherbourg"

# 2등석에서 비어 있으면 'Southampton'으로
mask = (df["class"] == "Second") & (df["embark_town"].isna())
df.loc[mask, "embark_town"] = "Southampton"

# 3등석에서 비어 있으면 'Southampton'으로
mask = (df["class"] == "Third") & (df["embark_town"].isna())
df.loc[mask, "embark_town"] = "Southampton"

# %%
   df["deck"] = df["deck"].astype("category")
   df["deck"] = df["deck"].cat.add_categories(["Unknown"])
   df["deck"] = df["deck"].fillna("Unknown")

# %%
sns.histplot(data=df_imp, x="age", hue="class", kde=True, element="step")
sns.boxplot(data=df_imp, x="class", y="fare")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
pd.crosstab(df_imp["class"], df_imp["embark_town"], normalize="index").round(2)
# Out:
# embark_town  Cherbourg  Queenstown  Southampton
# class
# First             0.40        0.01         0.59
# Second            0.09        0.02         0.89
# Third             0.13        0.15         0.72

# %%
sns.histplot(df_imp[df_imp["class"]=="First"]["age"], kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(data=df_imp[df_imp["sex"]=="female"], x="class", y="age")
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
iris = sns.load_dataset("iris")
tips = sns.load_dataset("tips")
penguins = sns.load_dataset("penguins")

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.hist(iris["sepal_length"], bins=20, alpha=0.8)
ax.set_title("Iris · Sepal Length (Histogram)")
ax.set_xlabel("sepal_length"); ax.set_ylabel("count")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6,4), dpi=120)
ax.plot(x, y, marker='o', linestyle='--')
ax.set_title("제목"); ax.set_xlabel("X"); ax.set_ylabel("Y")
ax.grid(True, linestyle=':')
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 2
#       1 fig, ax = plt.subplots(figsize=(6,4), dpi=120)
# ----> 2 ax.plot(x, y, marker='o', linestyle='--')
#       3 ax.set_title("제목"); ax.set_xlabel("X"); ax.set_ylabel("Y")
#       4 ax.grid(True, linestyle=':')
#
# NameError: name 'x' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) 예시 데이터
x = np.linspace(0, 10, 21)
y = np.sin(x)  # 임의로 사인 곡선을 사용

# 2) 객체지향 인터페이스로 그리기
fig, ax = plt.subplots(figsize=(6, 4), dpi=120)
ax.plot(x, y, marker='o', linestyle='--')   # 색상은 지정하지 않음
ax.set_title("사인 곡선 예시")
ax.set_xlabel("X")
ax.set_ylabel("sin(X)")
ax.grid(True, linestyle=':')
fig.tight_layout()

# 3) 파일로 저장(선택)
fig.savefig("/mnt/data/mpl_line_example.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# /var/folders/6p/kc5wj8m97yv4r_zm5y1n5kk00000gn/T/ipykernel_2282/3949591201.py:15: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /var/folders/6p/kc5wj8m97yv4r_zm5y1n5kk00000gn/T/ipykernel_2282/3949591201.py:15: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /var/folders/6p/kc5wj8m97yv4r_zm5y1n5kk00000gn/T/ipykernel_2282/3949591201.py:15: UserWarning: Glyph 44257 (\N{HANGUL SYLLABLE GOG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /var/folders/6p/kc5wj8m97yv4r_zm5y1n5kk00000gn/T/ipykernel_2282/3949591201.py:15: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /var/folders/6p/kc5wj8m97yv4r_zm5y1n5kk00000gn/T/ipykernel_2282/3949591201.py:15: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Line/Scatter용 연속형 데이터
x_line = np.linspace(0, 10, 30)
y_line = np.sin(x_line)

x_scatter = np.linspace(0, 10, 60)
y_scatter = 0.7 * x_scatter + np.random.randn(len(x_scatter)) * 1.2

# %%
fig, ax = plt.subplots(figsize=(6, 4), dpi=120)
ax.plot(x_line, y_line, marker='o', linestyle='--')
ax.set_title("Line Plot (Matplotlib)")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.grid(True, linestyle=':')
fig.tight_layout()
plt.show()

# %%
df_line = pd.DataFrame({"x": x_line, "y": y_line})

fig, ax = plt.subplots(figsize=(6, 4), dpi=120)
sns.lineplot(data=df_line, x="x", y="y", marker="o", ax=ax)
ax.set_title("Line Plot (Seaborn)")
ax.grid(True, linestyle=":")
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.hist(iris["sepal_length"], bins=20, alpha=0.8)
ax.set_title("Iris · Sepal Length (Histogram)")
ax.set_xlabel("sepal_length"); ax.set_ylabel("count")
plt.show()

# %%
num = iris.select_dtypes("number")
corr = num.corr()

# %%
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(corr, annot=True, fmt=".2f", square=True)
plt.title("Correlation Matrix (Iris)"); plt.show()
